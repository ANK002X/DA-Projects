# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataLink = "https://data.cityofchicago.org/resource/t7ek-mgzi.json?$order=id&$limit=100000&$offset=0"
data = pd.read_json(dataLink)

data
# Out:
#              id case_number                date                     block  \
# 0         28545    JJ100205 2025-01-01 03:57:00       094XX S HARVARD AVE
# 1         28546    JJ100293 2025-01-01 06:10:00  022XX S CENTRAL PARK AVE
# 2         28547    JJ100596 2025-01-01 14:06:00        075XX S RACINE AVE
# 3         28548    JJ100160 2025-01-02 01:18:00        012XX S SAWYER AVE
# 4         28549    JJ100988 2025-01-01 20:15:00       015XX W WARREN BLVD
# ...         ...         ...                 ...                       ...
# 28263  13760161    JJ163061 2025-01-29 12:00:00      078XX S EXCHANGE AVE
# 28264  13760168    JJ162055 2025-01-15 00:00:00        073XX S RACINE AVE
# 28265  13760202    JJ163210 2025-02-18 00:01:00      049XX S MICHIGAN AVE
# 28266  13760249    JJ163218 2025-01-05 02:00:00          035XX N CLARK ST
# 28267  13760376    JJ161260 2025-02-15 18:00:00        079XX S NORMAL AVE
#
#        iucr         primary_type                       description  \
# 0      0110             HOMICIDE               FIRST DEGREE MURDER
# 1      0110             HOMICIDE               FIRST DEGREE MURDER
# 2      0110             HOMICIDE               FIRST DEGREE MURDER
# 3      0110             HOMICIDE               FIRST DEGREE MURDER
# 4      0110             HOMICIDE               FIRST DEGREE MURDER
# ...     ...                  ...                               ...
# 28263  0915  MOTOR VEHICLE THEFT            TRUCK, BUS, MOTOR HOME
# 28264  1562          SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 28265  0610             BURGLARY                    FORCIBLE ENTRY
# 28266  0810                THEFT                         OVER $500
# 28267  0820                THEFT                    $500 AND UNDER
#
#                   location_description  arrest  domestic  ...  ward  \
# 0                                 YARD   False     False  ...     9
# 1                            APARTMENT    True      True  ...    22
# 2                               TAVERN   False     False  ...    17
# 3                                HOUSE    True      True  ...    24
# 4                            APARTMENT    True     False  ...    27
# ...                                ...     ...       ...  ...   ...
# 28263  OTHER COMMERCIAL TRANSPORTATION   False     False  ...     7
# 28264                            ALLEY   False      True  ...    17
# 28265                        APARTMENT   False     False  ...     3
# 28266                    BAR OR TAVERN   False     False  ...    44
# 28267                        APARTMENT   False     False  ...     6
#
#        community_area  fbi_code  x_coordinate y_coordinate  year  \
# 0                  49       01A     1175662.0    1842226.0  2025
# 1                  30       01A     1152723.0    1888730.0  2025
# 2                  71       01A     1169629.0    1854690.0  2025
# 3                  29       01A     1154891.0    1894243.0  2025
# 4                  28       01A     1166006.0    1900436.0  2025
# ...               ...       ...           ...          ...   ...
# 28263              43        07           NaN          NaN  2025
# 28264              67        17           NaN          NaN  2025
# 28265              38        05           NaN          NaN  2025
# 28266               6        06           NaN          NaN  2025
# 28267              44        06           NaN          NaN  2025
#
#                     updated_on   latitude  longitude  \
# 0      2025-01-09T15:41:07.000  41.722435 -87.632169
# 1      2025-02-15T15:41:00.000  41.850530 -87.714967
# 2      2025-01-09T15:41:07.000  41.756770 -87.653906
# 3      2025-01-10T15:41:24.000  41.865616 -87.706862
# 4      2025-01-09T15:41:07.000  41.882380 -87.665882
# ...                        ...        ...        ...
# 28263  2025-02-27T15:41:01.000        NaN        NaN
# 28264  2025-02-27T15:41:01.000        NaN        NaN
# 28265  2025-02-27T15:41:01.000        NaN        NaN
# 28266  2025-02-27T15:41:01.000        NaN        NaN
# 28267  2025-02-27T15:41:01.000        NaN        NaN
#
#                                                 location
# 0      {'type': 'Point', 'coordinates': [-87.63216880...
# 1      {'type': 'Point', 'coordinates': [-87.71496693...
# 2      {'type': 'Point', 'coordinates': [-87.65390643...
# 3      {'type': 'Point', 'coordinates': [-87.70686228...
# 4      {'type': 'Point', 'coordinates': [-87.66588180...
# ...                                                  ...
# 28263                                                NaN
# 28264                                                NaN
# 28265                                                NaN
# 28266                                                NaN
# 28267                                                NaN
#
# [28268 rows x 22 columns]

# %%
data.shape
# Out:
# (10000, 22)
